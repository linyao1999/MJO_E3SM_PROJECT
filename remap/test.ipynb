# %%
import xarray as xr

# %%
fn = 'grid_latlon90x180.nc'
ds = xr.open_dataset(fn)
ds
# Out:
# <xarray.Dataset>
# Dimensions:          (grid_rank: 2, grid_size: 16200, grid_corners: 4)
# Dimensions without coordinates: grid_rank, grid_size, grid_corners
# Data variables:
#     grid_dims        (grid_rank) int32 ...
#     grid_area        (grid_size) float64 ...
#     grid_imask       (grid_size) int32 ...
#     grid_center_lat  (grid_size) float64 ...
#     grid_center_lon  (grid_size) float64 ...
#     grid_corner_lat  (grid_size, grid_corners) float64 ...
#     grid_corner_lon  (grid_size, grid_corners) float64 ...
# Attributes:
#     title:                Equi-Angular grid, dimensions [lat, lon], cell edge...
#     Conventions:          SCRIP
#     created_by:           e4s
#     grid_generator:       NCO
#     history:              Wed Sep 13 15:24:38 2023: ncks -O --dmm_in_mk --no_...
#     NCO:                  netCDF Operators version 5.0.1 (Homepage = http://n...
#     latitude_grid_type:   Uniform/Equi-Angular latitude grid. Uniform/Equi-an...
# ...

# %%
ds['grid_dims'].values
# Out:
# array([180,  90], dtype=int32)
